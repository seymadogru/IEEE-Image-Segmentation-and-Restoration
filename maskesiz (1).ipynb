# %% [markdown]
# # Ortam Hazırlanması

# %%
# ORTAM KURULUMU
import os
import sys
import gc
import torch
from google.colab import drive

# 1. GPU Bellek Temizliği
gc.collect()
torch.cuda.empty_cache()

# 2. Google Drive Bağlantısı
if not os.path.exists('/content/drive'):
    print("[BİLGİ] Google Drive bağlanıyor...")
    drive.mount('/content/drive')

# 3. Gerekli Kütüphanelerin Kurulumu
print("[BİLGİ] Bağımlılıklar kuruluyor...")
os.system('pip install basicsr -q')
os.system('apt-get install p7zip-full -y -qq')

# 4. HAT Mimarisinin Klonlanması
if not os.path.exists('/content/HAT'):
    print("[BİLGİ] HAT deposu klonlanıyor...")
    os.system('git clone https://github.com/XPixelGroup/HAT.git /content/HAT')

# 5. Sistem Yollarının Tanımlanması
sys.path.append('/content/HAT')
sys.path.append('/content/HAT/hat/archs')

# 6. Registry Çakışması Düzeltmesi
try:
    from basicsr.utils.registry import ARCH_REGISTRY
    if hasattr(ARCH_REGISTRY, '_obj_map'): ARCH_REGISTRY._obj_map.clear()
except: pass

# 7. Donanım Kontrolü
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"[SİSTEM] Kullanılan Donanım: {torch.cuda.get_device_name(0)}")
# Out:
# [BİLGİ] Google Drive bağlanıyor...
# Mounted at /content/drive
# [BİLGİ] Bağımlılıklar kuruluyor...
# [BİLGİ] HAT deposu klonlanıyor...
# [SİSTEM] Kullanılan Donanım: NVIDIA A100-SXM4-80GB

# %% [markdown]
# # Veri setinin hazırlanması

# %%
# VERİ SETİ HAZIRLIĞI
import glob
import os

DATASET_ROOT = "/content/dataset"
IMG_FOLDER = os.path.join(DATASET_ROOT, "img")

# Bilinen şifreler listesi
passwords = [
    "mmlab_DeepFashion_inshop",          # In-shop Clothes Retrieval
    "mmlab_DeepFashion_consumer2shop",   # Consumer-to-shop
    "mmlab_DeepFashion_fashionsynth",    # Fashion Synthesis
]

# Veri seti henüz çıkarılmamışsa işlem başlatılır
if not os.path.exists(IMG_FOLDER):
    print("[İŞLEM] Veri seti arşivden çıkarılıyor...")

    # Drive üzerindeki olası zip yolları
    zip_paths = [
        "/content/drive/MyDrive/Görüntü Analizinde Derin Öğrenme Yöntemleri/DeepFashion/Img/img.zip",
        "/content/drive/MyDrive/Görüntü Analizinde Derin Öğrenme Yöntemleri/DeepFashion/Img/img_highres.zip"
    ]

    target_zip = None
    for p in zip_paths:
        if os.path.exists(p):
            target_zip = p
            print(f"[TESPİT] Zip dosyası bulundu: {p}")
            break

    if target_zip:
        os.makedirs(DATASET_ROOT, exist_ok=True)

        success = False
        # Şifre listesindeki her bir şifreyi sırayla dener
        for pwd in passwords:
            print(f"[DENEME] Şifre ile çıkarma deneniyor: {pwd}...")
            # -p bayrağı ile şifre verilir, hata çıktıları gizlenir (> /dev/null)
            exit_code = os.system(f'7z x "{target_zip}" -p"{pwd}" -o"{DATASET_ROOT}" -y > /dev/null 2>&1')

            if exit_code == 0:
                print(f"[BAŞARILI] Doğru şifre bulundu ve arşiv açıldı: {pwd}")
                success = True
                break

        # Eğer hiçbir şifre çalışmazsa, şifresiz deneme yapılır
        if not success:
            print("[UYARI] Şifreler kabul edilmedi, şifresiz deneme yapılıyor...")
            os.system(f'7z x "{target_zip}" -o"{DATASET_ROOT}" -y > /dev/null 2>&1')

        # Çıkarılan dosyaların konumunun doğrulanması ve yolun ayarlanması
        found_jpgs = glob.glob(f"{DATASET_ROOT}/**/*.jpg", recursive=True)
        if found_jpgs:
            # jpg dosyalarının bulunduğu ana dizini bul
            IMG_FOLDER = os.path.dirname(found_jpgs[0])
            # Klasör yapısı 'WOMEN/Blouse/...' şeklindeyse üst dizine çık
            if "WOMEN" in IMG_FOLDER: IMG_FOLDER = IMG_FOLDER.split('/WOMEN')[0]
            elif "MEN" in IMG_FOLDER: IMG_FOLDER = IMG_FOLDER.split('/MEN')[0]
            print(f"[BAŞARILI] Veri seti ana dizini ayarlandı: {IMG_FOLDER}")
        else:
             print("[HATA] Zip çıkarıldı ancak içinde .jpg dosyası bulunamadı.")
    else:
        print("[HATA] Zip dosyası Google Drive yolunda bulunamadı. Lütfen dosya yolunu kontrol ediniz.")
else:
    print("[BİLGİ] Veri seti zaten mevcut, çıkarma işlemi atlanıyor.")
# Out:
# [İŞLEM] Veri seti arşivden çıkarılıyor...
# [TESPİT] Zip dosyası bulundu: /content/drive/MyDrive/Görüntü Analizinde Derin Öğrenme Yöntemleri/DeepFashion/Img/img.zip
# [DENEME] Şifre ile çıkarma deneniyor: mmlab_DeepFashion_inshop...
# [BAŞARILI] Doğru şifre bulundu ve arşiv açıldı: mmlab_DeepFashion_inshop
# [BAŞARILI] Veri seti ana dizini ayarlandı: /content/dataset/img

# %% [markdown]
# # Veri Yükleme ve Dinamik Leke Maskeleme

# %%
# VERİ SETİ AYRIMI (%90 EĞİTİM - %10 TEST) VE LEKE MASKELEME
import random
import glob
import os
import cv2
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

# 1. Görüntü Yollarının Toplanması ve Ayrıştırılması
print("[İŞLEM] Veri setindeki tüm görüntüler taranıyor...")
all_image_paths = sorted(glob.glob(os.path.join(IMG_FOLDER, '**', '*.jpg'), recursive=True))

# Veri sayısı kontrolü
total_images = len(all_image_paths)
if total_images == 0:
    raise ValueError(f"[HATA] '{IMG_FOLDER}' konumunda hiç .jpg dosyası bulunamadı. Lütfen Hücre 2'yi kontrol ediniz.")

# Rastgele Karıştırma (Shuffle) - Her seferinde farklı dağılım olmaması için seed sabitlenebilir
random.seed(42)
random.shuffle(all_image_paths)

# %90 Eğitim, %10 Test Ayrımı
split_index = int(total_images * 0.90)
train_paths = all_image_paths[:split_index]
test_paths = all_image_paths[split_index:]

# İstatistiklerin Yazdırılması
print("\n" + "="*40)
print("VERİ SETİ DAĞILIM RAPORU")
print("="*40)
print(f"Toplam Görüntü Sayısı : {total_images}")
print(f"Eğitim Seti (%90)     : {len(train_paths)}")
print(f"Test Seti (%10)       : {len(test_paths)}")
print("="*40 + "\n")

# 2. Dataset Sınıfı
class FashionInpaintingDataset(Dataset):
    def __init__(self, paths, img_size=128):
        """
        paths: Görüntü dosya yollarının listesi (train_paths veya test_paths)
        """
        self.img_paths = paths
        self.img_size = img_size

    def generate_paint_splatter_mask(self, h, w):
        """
        Boya sıçraması efektini simüle eden maske üretim fonksiyonu.
        """
        mask = np.zeros((h, w), dtype=np.float32)

        # Leke sayısı (Yoğunluk)
        num_splatters = random.randint(5, 15)

        for _ in range(num_splatters):
            cx, cy = random.randint(0, w), random.randint(0, h)
            radius = random.randint(2, 5) # Küçük lekeler
            cv2.circle(mask, (cx, cy), radius, 1.0, -1)

            # Ana leke etrafına saçılan mikro lekeler (Sıçrama efekti)
            for _ in range(random.randint(3, 8)):
                ox = cx + random.randint(-radius*2, radius*2)
                oy = cy + random.randint(-radius*2, radius*2)
                ox = max(0, min(w-1, ox))
                oy = max(0, min(h-1, oy))
                cv2.circle(mask, (ox, oy), 1, 1.0, -1)

        return mask

    def __getitem__(self, index):
        try:
            path = self.img_paths[index % len(self.img_paths)]
            img = cv2.imread(path)
            if img is None: raise ValueError
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (self.img_size, self.img_size))
        except: return self.__getitem__(index + 1)

        # Dinamik maske üretimi
        mask = self.generate_paint_splatter_mask(self.img_size, self.img_size)

        # Görüntüyü maskeleme
        img_input = img.copy() * (1 - np.repeat(mask[:, :, np.newaxis], 3, axis=2))

        # Tensör dönüşümü
        return {'input': torch.from_numpy(img_input.transpose(2,0,1)).float()/255.0,
                'mask': torch.from_numpy(mask[np.newaxis,:,:]).float(),
                'gt': torch.from_numpy(img.transpose(2,0,1)).float()/255.0}

    def __len__(self): return len(self.img_paths)

# 3. DataLoader Tanımlamaları
# Eğitim Yükleyicisi
train_dataset = FashionInpaintingDataset(train_paths, img_size=128)
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)

# Test Yükleyicisi (Sonuçları görselleştirirken bunu kullanacağız)
test_dataset = FashionInpaintingDataset(test_paths, img_size=128)
test_dataloader = DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers=2)

# Sonraki hücrelerle uyumluluk için ana değişken ataması
dataloader = train_dataloader

print("[DURUM] Eğitim ve Test veri yükleyicileri (DataLoaders) hazırlandı.")
# Out:
# [İŞLEM] Veri setindeki tüm görüntüler taranıyor...
#
# ========================================
# VERİ SETİ DAĞILIM RAPORU
# ========================================
# Toplam Görüntü Sayısı : 52712
# Eğitim Seti (%90)     : 47440
# Test Seti (%10)       : 5272
# ========================================
#
# [DURUM] Eğitim ve Test veri yükleyicileri (DataLoaders) hazırlandı.

# %%
# VERİ KONTROLÜ (EĞİTİM ÖNCESİ GÖRSELLEŞTİRME)
import matplotlib.pyplot as plt
import numpy as np
import torch

def check_data_augmentation(loader, num_samples=4):
    print("[İŞLEM] Veri yükleyiciden rastgele örnekler çekiliyor...")

    # Dataloader'dan bir batch (grup) veri al
    iter_loader = iter(loader)
    try:
        batch = next(iter_loader)
    except StopIteration:
        iter_loader = iter(loader)
        batch = next(iter_loader)


    masked_imgs = batch['input']
    masks = batch['mask']
    real_imgs = batch['gt']

    # Görselleştirme
    plt.figure(figsize=(15, 5 * num_samples))

    for i in range(num_samples):
        # Tensörleri (C, H, W) -> Numpy (H, W, C) formatına çevir
        # .permute(1, 2, 0) kanalları en sona alır
        img_in = masked_imgs[i].permute(1, 2, 0).numpy()
        mask_in = masks[i].permute(1, 2, 0).numpy()
        img_gt = real_imgs[i].permute(1, 2, 0).numpy()

        # 1. Lekeli Görüntü (Modelin Gireceği Veri)
        plt.subplot(num_samples, 3, i*3 + 1)
        plt.imshow(np.clip(img_in, 0, 1))
        plt.title("Eğitim Girdisi (Lekeli)")
        plt.axis('off')

        # 2. Üretilen Maske (Modelin Bulması Gereken Yer)
        plt.subplot(num_samples, 3, i*3 + 2)
        plt.imshow(mask_in.squeeze(), cmap='gray', vmin=0, vmax=1)
        plt.title("Uygulanan Maske (Boya Sıçraması)")
        plt.axis('off')

        # 3. Orijinal Görüntü (Hedef)
        plt.subplot(num_samples, 3, i*3 + 3)
        plt.imshow(np.clip(img_gt, 0, 1))
        plt.title("Orijinal Görüntü")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Fonksiyonu eğitim veri setinden örneklerle çalıştır
print("[BİLGİ] Rastgele boya sıçraması örnekleri gösteriliyor...")
check_data_augmentation(dataloader, num_samples=3)
# Out:
# [BİLGİ] Rastgele boya sıçraması örnekleri gösteriliyor...
# [İŞLEM] Veri yükleyiciden rastgele örnekler çekiliyor...

# %% [markdown]
# # Önerilen Model Mimarisi (Mask Guided HAT)

# %%
import os
import sys
import torch
import torch.nn as nn
import torchvision.transforms.functional as F

# --- DÜZELTME 1: TORCHVISION UYUMSUZLUĞU ---
# Yeni torchvision sürümlerinde kaldırılan modülü yamalıyoruz
try:
    import torchvision.transforms.functional_tensor
except ImportError:
    sys.modules['torchvision.transforms.functional_tensor'] = F

# --- DÜZELTME 2: REGISTRY ÇAKIŞMASI ---
# "HAT already registered" hatasını önlemek için kayıt defterini temizliyoruz
try:
    from basicsr.utils.registry import ARCH_REGISTRY
    if hasattr(ARCH_REGISTRY, '_obj_map'):
        ARCH_REGISTRY._obj_map.clear()
        print("[BAKIM] Model kayıt defteri temizlendi.")
except ImportError:
    pass

# --- DÜZELTME 3: HATALI DOSYA TEMİZLİĞİ ---
problematic_file = '/content/HAT/hat/data/imagenet_paired_dataset.py'
if os.path.exists(problematic_file):
    os.remove(problematic_file)

# --- MODEL İMPORT İŞLEMİ ---
try:
    from hat.archs.hat_arch import HAT as OriginalHAT
except ImportError:
    sys.path.append('/content/HAT/hat/archs')
    from hat_arch import HAT as OriginalHAT

# --- YENİ MODEL SINIFI (MASKE REHBERLİĞİ OLMAYAN BLIND VERSİYON) ---
class BlindHAT(nn.Module):
    def __init__(self, img_size=128):
        super(BlindHAT, self).__init__()

        # 1. Kodlayıcı Omurga (Backbone): HAT
        self.hat = OriginalHAT(img_size=img_size, embed_dim=180, upscale=1, window_size=8)
        if hasattr(self.hat, 'conv_last'): del self.hat.conv_last

        # DİKKAT: Segmentasyon bloğu (seg_head) bu versiyonda tamamen çıkarıldı!

        # 2. Restorasyon Bloğu (Leke Temizleme)
        self.inpaint_head = nn.Sequential(
            # Girdi 181'den 180'e düşürüldü (Maske kanalı iptal edildi, sadece HAT özellikleri giriyor)
            nn.Conv2d(180, 128, 3, 1, 1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128, 64, 3, 1, 1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 3, 3, 1, 1),
            nn.Sigmoid() # Çıktı: 0-1 aralığında RGB görüntü
        )

    def forward_backbone(self, x):
        # HAT mimarisinin ileri besleme işlemleri (Değişiklik yapılmadı)
        x = self.hat.conv_first(x)
        shortcut = x
        if hasattr(self.hat, 'patch_embed'): x = self.hat.patch_embed(x)
        if hasattr(self.hat, 'layers'):
            x_size = (x.size(2), x.size(3)) if x.dim() == 4 else (int(x.size(1)**0.5), int(x.size(1)**0.5))
            rpi_sa = getattr(self.hat, 'relative_position_index_SA', None)
            rpi_oca = getattr(self.hat, 'relative_position_index_OCA', None)
            params = {'rpi_sa': rpi_sa, 'rpi_oca': rpi_oca, 'attn_mask': None}
            for layer in self.hat.layers:
                try: x = layer(x, x_size, params)
                except: x = layer(x, x_size)
        if hasattr(self.hat, 'norm'): x = self.hat.norm(x)
        if hasattr(self.hat, 'patch_unembed'): x = self.hat.patch_unembed(x, x_size)
        x = self.hat.conv_after_body(x)
        x = x + shortcut
        return x

    def forward(self, x):
        # Öznitelik Çıkarımı
        feat = self.forward_backbone(x)

        # Maske hesaplama ve torch.cat (birleştirme) işlemleri iptal edildi.
        # HAT'tan gelen 180 kanallı saf özellikler doğrudan inpaint_head'e veriliyor.
        restored_img = self.inpaint_head(feat)

        # Artık maske üretmediğimiz için sadece onarılmış resmi döndürüyoruz
        return restored_img

# Modelin GPU'ya yüklenmesi
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BlindHAT(img_size=128).to(device)
print("[DURUM] BlindHAT (Maskesiz) modeli başarıyla başlatıldı.")
# Out:
# [BAKIM] Model kayıt defteri temizlendi.
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [DURUM] BlindHAT (Maskesiz) modeli başarıyla başlatıldı.

# %%
# EĞİTİM KONFİGÜRASYONU (BLIND / MASKESİZ MODEL İÇİN)
import torch
import torch.nn as nn
import torchvision.models as models
from hat.archs.discriminator_arch import UNetDiscriminatorSN
from torch.utils.data import DataLoader

NUM_EPOCHS = 10
BATCH_SIZE = 16
LR = 1e-4

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
dataloader = train_dataloader # Ana döngü için atama

# DİKKAT: BCEDiceLoss sınıfı ve criterion_bce bu versiyonda tamamen çıkarıldı!
# Çünkü BlindHAT modeli maske tahmini yapmıyor.

# Kayıp Fonksiyonları (Sadece piksel bazlı kayıp kaldı)
criterion_l1 = nn.L1Loss()

# VGG Ağı (Algısal Kayıp için - Dondurulmuş ağırlıklar)
vgg = models.vgg19(weights=models.VGG19_Weights.DEFAULT).features[:35].eval().to(device)
for p in vgg.parameters(): p.requires_grad = False

# Discriminator (Ayırt Edici Ağ)
discriminator = UNetDiscriminatorSN(num_in_ch=3).to(device)

# DİKKAT: MaskGuidedHAT yerine BlindHAT çağrılıyor!
model = BlindHAT(img_size=128).to(device)
print("[DURUM] BlindHAT (Maskesiz) modeli başarıyla başlatıldı.")

# Optimizasyon
optimizer_G = torch.optim.Adam(model.parameters(), lr=LR, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=LR, betas=(0.5, 0.999))

# Karma Hassasiyet (AMP) Hızlandırıcı
scaler = torch.cuda.amp.GradScaler()

print(f"[BİLGİ] Eğitim konfigürasyonu A100 GPU ve MASKESİZ (Blind) model için ayarlandı. Batch Size: {BATCH_SIZE}")
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:02<00:00, 228MB/s]
# [DURUM] BlindHAT (Maskesiz) modeli başarıyla başlatıldı.
# [BİLGİ] Eğitim konfigürasyonu A100 GPU ve MASKESİZ (Blind) model için ayarlandı. Batch Size: 16
# /tmp/ipykernel_3496/2253165001.py:38: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %% [markdown]
# # Hiperparametreler ve Kayıp Fonksiyonları

# %% [markdown]
# # Training

# %%
# EĞİTİM DÖNGÜSÜ (BLIND / MASKESİZ MODEL İÇİN)
import torch
import gc
import torch.nn.functional as F
import os

# --- DRIVE KAYIT KLASÖRÜ HAZIRLIĞI ---
kayit_klasoru = "/content/drive/MyDrive/Goruntu_Analizi_Projesi/Modeller"
os.makedirs(kayit_klasoru, exist_ok=True)
print(f"[BİLGİ] Modeller Drive'da şu konuma kaydedilecek: {kayit_klasoru}")

# --- BELLEK TEMİZLİĞİ ---
print("GPU Belleği temizleniyor...")
gc.collect()
torch.cuda.empty_cache()
print("-" * 30)

print(f"\n[BAŞLANGIÇ] MASKESİZ (Blind) Model Eğitimi {NUM_EPOCHS} Epoch boyunca başlıyor...")

# En iyi kaybı takip etmek için başlangıç değeri (Sonsuz)
best_loss = float('inf')

for epoch in range(NUM_EPOCHS):
    model.train()
    total_loss_g = 0

    for i, batch in enumerate(dataloader):
        real = batch['gt'].to(device)
        masked = batch['input'].to(device)

        # Maskesiz modelde mask verisine ihtiyacımız olmadığı için o satırı da kaldırdık.

        # --- Generator Eğitimi ---
        optimizer_G.zero_grad()
        with torch.cuda.amp.autocast():
            # DİKKAT: Model artık sadece onarılmış resmi (p_img) üretiyor. Maske çıktısı yok.
            p_img = model(masked)

            # Toplam Kayıp Hesaplama (Maske kaybı (BCE) çıkarıldı)
            loss_pix = 1.0 * criterion_l1(p_img, real)                 # Piksel doğruluğu
            loss_perc = 5.0 * criterion_l1(vgg(p_img), vgg(real))      # Doku kalitesi

            # GAN Generator kaybında EKSİ işareti
            loss_adv = -0.1 * torch.mean(discriminator(p_img))         # Gerçekçilik

            # Maske kaybı olmadığı için sadece diğer üçünü topluyoruz
            loss_G = loss_pix + loss_perc + loss_adv

        scaler.scale(loss_G).backward()
        scaler.step(optimizer_G)
        scaler.update()

        # --- Discriminator Eğitimi ---
        optimizer_D.zero_grad()
        with torch.cuda.amp.autocast():
            d_real = discriminator(real)
            d_fake = discriminator(p_img.detach())
            # Hinge Loss
            loss_D = (torch.mean(F.relu(1.0 - d_real)) + torch.mean(F.relu(1.0 + d_fake))) / 2.0

        scaler.scale(loss_D).backward()
        scaler.step(optimizer_D)
        scaler.update()

        total_loss_g += loss_G.item()

        # Loglama sıklığı
        if i % 200 == 0:
            print(f"Epoch [{epoch+1}/{NUM_EPOCHS}] Adım {i} | Loss G: {loss_G.item():.4f} | Loss D: {loss_D.item():.4f}")

    avg_loss = total_loss_g / len(dataloader)
    print(f"[TAMAMLANDI] Epoch {epoch+1} Bitti. Ortalama Generator Kaybı: {avg_loss:.4f}")

    # --- MODELİ DRIVE'A KAYDETME İŞLEMİ ---

    # DİKKAT: Asıl modelinin üzerine yazmasın diye isimleri "blind_" olarak güncelledim!

    # 1. Her epoch sonunda güncel modeli garantilemek için kaydet
    guncel_model_yolu = os.path.join(kayit_klasoru, "blind_guncel_model.pth")
    torch.save(model.state_dict(), guncel_model_yolu)
    print(f" -> [KAYIT] Güncel Blind model Drive'a yedeklendi.")

    # 2. Eğer bu epoch'taki kayıp (loss) rekor kırdıysa, "en iyi" olarak kaydet
    if avg_loss < best_loss:
        best_loss = avg_loss
        en_iyi_model_yolu = os.path.join(kayit_klasoru, "blind_en_iyi_model.pth")
        torch.save(model.state_dict(), en_iyi_model_yolu)
        print(f" -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: {best_loss:.4f})")

    print("-" * 60)

# Tüm eğitim sorunsuz bittiğinde son bir kayıt
tamamlanmis_model_yolu = os.path.join(kayit_klasoru, "blind_tamamlanmis_model.pth")
torch.save(model.state_dict(), tamamlanmis_model_yolu)
print("\n[EĞİTİM SONU] Blind model eğitimi bitti ve son model Drive'a başarıyla kaydedildi!")
# Out:
# [BİLGİ] Modeller Drive'da şu konuma kaydedilecek: /content/drive/MyDrive/Goruntu_Analizi_Projesi/Modeller
# GPU Belleği temizleniyor...
# ------------------------------
#
# [BAŞLANGIÇ] MASKESİZ (Blind) Model Eğitimi 10 Epoch boyunca başlıyor...
# /tmp/ipykernel_3496/545658603.py:35: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /tmp/ipykernel_3496/545658603.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch [1/10] Adım 0 | Loss G: 10.1869 | Loss D: 0.9883
# Epoch [1/10] Adım 200 | Loss G: 6.1482 | Loss D: 0.9756
# Epoch [1/10] Adım 400 | Loss G: 2.6542 | Loss D: 0.9951
# Epoch [1/10] Adım 600 | Loss G: 2.3259 | Loss D: 0.9688
# Epoch [1/10] Adım 800 | Loss G: 1.7200 | Loss D: 0.9922
# Epoch [1/10] Adım 1000 | Loss G: 1.5610 | Loss D: 0.9565
# Epoch [1/10] Adım 1200 | Loss G: 1.2883 | Loss D: 0.9600
# Epoch [1/10] Adım 1400 | Loss G: 1.2761 | Loss D: 0.9873
# Epoch [1/10] Adım 1600 | Loss G: 1.3637 | Loss D: 0.9902
# Epoch [1/10] Adım 1800 | Loss G: 1.0978 | Loss D: 0.9971
# Epoch [1/10] Adım 2000 | Loss G: 1.0801 | Loss D: 0.9985
# Epoch [1/10] Adım 2200 | Loss G: 0.8409 | Loss D: 0.9902
# Epoch [1/10] Adım 2400 | Loss G: 1.0720 | Loss D: 0.9912
# Epoch [1/10] Adım 2600 | Loss G: 0.9796 | Loss D: 0.9409
# Epoch [1/10] Adım 2800 | Loss G: 0.7735 | Loss D: 1.0059
# [TAMAMLANDI] Epoch 1 Bitti. Ortalama Generator Kaybı: 1.9519
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 1.9519)
# ------------------------------------------------------------
# Epoch [2/10] Adım 0 | Loss G: 1.0749 | Loss D: 1.0059
# Epoch [2/10] Adım 200 | Loss G: 0.7952 | Loss D: 0.9775
# Epoch [2/10] Adım 400 | Loss G: 0.8873 | Loss D: 0.9917
# Epoch [2/10] Adım 600 | Loss G: 0.6811 | Loss D: 0.9971
# Epoch [2/10] Adım 800 | Loss G: 0.9427 | Loss D: 1.0039
# Epoch [2/10] Adım 1000 | Loss G: 0.8849 | Loss D: 0.9956
# Epoch [2/10] Adım 1200 | Loss G: 0.9598 | Loss D: 1.0205
# Epoch [2/10] Adım 1400 | Loss G: 0.8297 | Loss D: 0.9917
# Epoch [2/10] Adım 1600 | Loss G: 0.9927 | Loss D: 0.9912
# Epoch [2/10] Adım 1800 | Loss G: 0.8377 | Loss D: 0.9912
# Epoch [2/10] Adım 2000 | Loss G: 0.7770 | Loss D: 0.9766
# Epoch [2/10] Adım 2200 | Loss G: 1.0160 | Loss D: 0.9829
# Epoch [2/10] Adım 2400 | Loss G: 0.7750 | Loss D: 0.9673
# Epoch [2/10] Adım 2600 | Loss G: 0.6840 | Loss D: 0.9966
# Epoch [2/10] Adım 2800 | Loss G: 0.6852 | Loss D: 0.9966
# [TAMAMLANDI] Epoch 2 Bitti. Ortalama Generator Kaybı: 0.8434
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 0.8434)
# ------------------------------------------------------------
# Epoch [3/10] Adım 0 | Loss G: 0.7023 | Loss D: 0.9922
# Epoch [3/10] Adım 200 | Loss G: 0.8336 | Loss D: 0.9844
# Epoch [3/10] Adım 400 | Loss G: 1.0668 | Loss D: 1.0156
# Epoch [3/10] Adım 600 | Loss G: 0.7959 | Loss D: 0.9746
# Epoch [3/10] Adım 800 | Loss G: 0.7629 | Loss D: 0.9966
# Epoch [3/10] Adım 1000 | Loss G: 0.8159 | Loss D: 1.0127
# Epoch [3/10] Adım 1200 | Loss G: 0.7348 | Loss D: 0.9902
# Epoch [3/10] Adım 1400 | Loss G: 0.6361 | Loss D: 0.9976
# Epoch [3/10] Adım 1600 | Loss G: 0.8189 | Loss D: 0.9829
# Epoch [3/10] Adım 1800 | Loss G: 0.9358 | Loss D: 0.9922
# Epoch [3/10] Adım 2000 | Loss G: 0.9126 | Loss D: 1.0029
# Epoch [3/10] Adım 2200 | Loss G: 0.6472 | Loss D: 0.9971
# Epoch [3/10] Adım 2400 | Loss G: 0.6400 | Loss D: 0.9966
# Epoch [3/10] Adım 2600 | Loss G: 0.5082 | Loss D: 0.9707
# Epoch [3/10] Adım 2800 | Loss G: 0.6128 | Loss D: 0.9922
# [TAMAMLANDI] Epoch 3 Bitti. Ortalama Generator Kaybı: 0.7509
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 0.7509)
# ------------------------------------------------------------
# Epoch [4/10] Adım 0 | Loss G: 0.7001 | Loss D: 0.9893
# Epoch [4/10] Adım 200 | Loss G: 0.8544 | Loss D: 0.9795
# Epoch [4/10] Adım 400 | Loss G: 0.7898 | Loss D: 1.0264
# Epoch [4/10] Adım 600 | Loss G: 0.8337 | Loss D: 0.9912
# Epoch [4/10] Adım 800 | Loss G: 0.6163 | Loss D: 0.9824
# Epoch [4/10] Adım 1000 | Loss G: 0.6683 | Loss D: 0.9912
# Epoch [4/10] Adım 1200 | Loss G: 0.5898 | Loss D: 0.9844
# Epoch [4/10] Adım 1400 | Loss G: 0.7649 | Loss D: 1.0039
# Epoch [4/10] Adım 1600 | Loss G: 0.7083 | Loss D: 1.0010
# Epoch [4/10] Adım 1800 | Loss G: 0.6867 | Loss D: 0.9883
# Epoch [4/10] Adım 2000 | Loss G: 0.6538 | Loss D: 1.0020
# Epoch [4/10] Adım 2200 | Loss G: 0.7959 | Loss D: 1.0361
# Epoch [4/10] Adım 2400 | Loss G: 0.5621 | Loss D: 0.9980
# Epoch [4/10] Adım 2600 | Loss G: 0.6378 | Loss D: 1.0234
# Epoch [4/10] Adım 2800 | Loss G: 0.7390 | Loss D: 0.9902
# [TAMAMLANDI] Epoch 4 Bitti. Ortalama Generator Kaybı: 0.6865
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 0.6865)
# ------------------------------------------------------------
# Epoch [5/10] Adım 0 | Loss G: 0.4871 | Loss D: 0.9961
# Epoch [5/10] Adım 200 | Loss G: 0.6120 | Loss D: 1.0010
# Epoch [5/10] Adım 400 | Loss G: 0.7513 | Loss D: 0.9922
# Epoch [5/10] Adım 600 | Loss G: 0.7056 | Loss D: 1.0098
# Epoch [5/10] Adım 800 | Loss G: 0.6802 | Loss D: 0.9922
# Epoch [5/10] Adım 1000 | Loss G: 0.6489 | Loss D: 1.0059
# Epoch [5/10] Adım 1200 | Loss G: 0.7105 | Loss D: 1.0029
# Epoch [5/10] Adım 1400 | Loss G: 0.5852 | Loss D: 0.9785
# Epoch [5/10] Adım 1600 | Loss G: 0.7616 | Loss D: 0.9893
# Epoch [5/10] Adım 1800 | Loss G: 0.6396 | Loss D: 1.0010
# Epoch [5/10] Adım 2000 | Loss G: 0.5620 | Loss D: 1.0098
# Epoch [5/10] Adım 2200 | Loss G: 0.4870 | Loss D: 0.9971
# Epoch [5/10] Adım 2400 | Loss G: 0.6494 | Loss D: 1.0195
# Epoch [5/10] Adım 2600 | Loss G: 0.6606 | Loss D: 0.9990
# Epoch [5/10] Adım 2800 | Loss G: 0.6281 | Loss D: 0.9922
# [TAMAMLANDI] Epoch 5 Bitti. Ortalama Generator Kaybı: 0.6589
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 0.6589)
# ------------------------------------------------------------
# Epoch [6/10] Adım 0 | Loss G: 0.5523 | Loss D: 1.0078
# Epoch [6/10] Adım 200 | Loss G: 0.7429 | Loss D: 0.9863
# Epoch [6/10] Adım 400 | Loss G: 0.6210 | Loss D: 0.9990
# Epoch [6/10] Adım 600 | Loss G: 0.6177 | Loss D: 0.9941
# Epoch [6/10] Adım 800 | Loss G: 0.6402 | Loss D: 0.9814
# Epoch [6/10] Adım 1000 | Loss G: 0.6089 | Loss D: 0.9893
# Epoch [6/10] Adım 1200 | Loss G: 0.6189 | Loss D: 1.0029
# Epoch [6/10] Adım 1400 | Loss G: 0.5893 | Loss D: 1.0137
# Epoch [6/10] Adım 1600 | Loss G: 0.5951 | Loss D: 0.9907
# Epoch [6/10] Adım 1800 | Loss G: 0.4786 | Loss D: 1.0029
# Epoch [6/10] Adım 2000 | Loss G: 0.6714 | Loss D: 1.0117
# Epoch [6/10] Adım 2200 | Loss G: 0.5954 | Loss D: 0.9805
# Epoch [6/10] Adım 2400 | Loss G: 0.5349 | Loss D: 0.9971
# Epoch [6/10] Adım 2600 | Loss G: 0.7529 | Loss D: 1.0059
# Epoch [6/10] Adım 2800 | Loss G: 0.6179 | Loss D: 0.9893
# [TAMAMLANDI] Epoch 6 Bitti. Ortalama Generator Kaybı: 0.6197
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 0.6197)
# ------------------------------------------------------------
# Epoch [7/10] Adım 0 | Loss G: 0.6481 | Loss D: 0.9956
# Epoch [7/10] Adım 200 | Loss G: 0.5026 | Loss D: 0.9858
# Epoch [7/10] Adım 400 | Loss G: 0.5362 | Loss D: 1.0010
# Epoch [7/10] Adım 600 | Loss G: 0.5829 | Loss D: 0.9814
# Epoch [7/10] Adım 800 | Loss G: 0.5257 | Loss D: 0.9971
# Epoch [7/10] Adım 1000 | Loss G: 0.6302 | Loss D: 1.0234
# Epoch [7/10] Adım 1200 | Loss G: 0.6632 | Loss D: 0.9766
# Epoch [7/10] Adım 1400 | Loss G: 0.5187 | Loss D: 1.0469
# Epoch [7/10] Adım 1600 | Loss G: 0.5034 | Loss D: 0.9980
# Epoch [7/10] Adım 1800 | Loss G: 0.7257 | Loss D: 0.9980
# Epoch [7/10] Adım 2000 | Loss G: 0.5782 | Loss D: 0.9824
# Epoch [7/10] Adım 2200 | Loss G: 0.5329 | Loss D: 0.9673
# Epoch [7/10] Adım 2400 | Loss G: 0.6357 | Loss D: 1.0088
# Epoch [7/10] Adım 2600 | Loss G: 0.7363 | Loss D: 0.9941
# Epoch [7/10] Adım 2800 | Loss G: 0.6072 | Loss D: 0.9854
# [TAMAMLANDI] Epoch 7 Bitti. Ortalama Generator Kaybı: 0.6003
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 0.6003)
# ------------------------------------------------------------
# Epoch [8/10] Adım 0 | Loss G: 0.6379 | Loss D: 0.9746
# Epoch [8/10] Adım 200 | Loss G: 0.5542 | Loss D: 0.9829
# Epoch [8/10] Adım 400 | Loss G: 0.5196 | Loss D: 0.9614
# Epoch [8/10] Adım 600 | Loss G: 0.5210 | Loss D: 0.9736
# Epoch [8/10] Adım 800 | Loss G: 0.6320 | Loss D: 0.9805
# Epoch [8/10] Adım 1000 | Loss G: 0.5138 | Loss D: 0.9419
# Epoch [8/10] Adım 1200 | Loss G: 0.4883 | Loss D: 0.9697
# Epoch [8/10] Adım 1400 | Loss G: 0.5835 | Loss D: 0.9912
# Epoch [8/10] Adım 1600 | Loss G: 0.7169 | Loss D: 0.9648
# Epoch [8/10] Adım 1800 | Loss G: 0.6480 | Loss D: 1.0166
# Epoch [8/10] Adım 2000 | Loss G: 0.5002 | Loss D: 0.9849
# Epoch [8/10] Adım 2200 | Loss G: 0.4777 | Loss D: 0.9922
# Epoch [8/10] Adım 2400 | Loss G: 0.4868 | Loss D: 0.9834
# Epoch [8/10] Adım 2600 | Loss G: 0.5608 | Loss D: 0.9561
# Epoch [8/10] Adım 2800 | Loss G: 0.5153 | Loss D: 0.9580
# [TAMAMLANDI] Epoch 8 Bitti. Ortalama Generator Kaybı: 0.5801
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 0.5801)
# ------------------------------------------------------------
# Epoch [9/10] Adım 0 | Loss G: 0.5803 | Loss D: 0.9688
# Epoch [9/10] Adım 200 | Loss G: 0.5054 | Loss D: 1.0137
# Epoch [9/10] Adım 400 | Loss G: 0.6349 | Loss D: 0.9775
# Epoch [9/10] Adım 600 | Loss G: 0.4539 | Loss D: 0.9834
# Epoch [9/10] Adım 800 | Loss G: 0.5044 | Loss D: 0.9912
# Epoch [9/10] Adım 1000 | Loss G: 0.5267 | Loss D: 0.9155
# Epoch [9/10] Adım 1200 | Loss G: 0.5695 | Loss D: 0.8955
# Epoch [9/10] Adım 1400 | Loss G: 0.5211 | Loss D: 0.9219
# Epoch [9/10] Adım 1600 | Loss G: 0.4158 | Loss D: 0.8828
# Epoch [9/10] Adım 1800 | Loss G: 0.5916 | Loss D: 0.9082
# Epoch [9/10] Adım 2000 | Loss G: 0.4526 | Loss D: 0.8555
# Epoch [9/10] Adım 2200 | Loss G: 0.6148 | Loss D: 0.8403
# Epoch [9/10] Adım 2400 | Loss G: 0.5586 | Loss D: 0.8647
# Epoch [9/10] Adım 2600 | Loss G: 0.5731 | Loss D: 0.8735
# Epoch [9/10] Adım 2800 | Loss G: 0.5554 | Loss D: 0.8076
# [TAMAMLANDI] Epoch 9 Bitti. Ortalama Generator Kaybı: 0.5661
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
#  -> [BAŞARI] Yeni en iyi Blind model Drive'a kaydedildi! (Kayıp: 0.5661)
# ------------------------------------------------------------
# Epoch [10/10] Adım 0 | Loss G: 0.5209 | Loss D: 0.8369
# Epoch [10/10] Adım 200 | Loss G: 0.5845 | Loss D: 0.6846
# Epoch [10/10] Adım 400 | Loss G: 0.6493 | Loss D: 0.7788
# Epoch [10/10] Adım 600 | Loss G: 0.7410 | Loss D: 0.7666
# Epoch [10/10] Adım 800 | Loss G: 0.7077 | Loss D: 0.7061
# Epoch [10/10] Adım 1000 | Loss G: 0.4490 | Loss D: 0.6885
# Epoch [10/10] Adım 1200 | Loss G: 0.4718 | Loss D: 0.7739
# Epoch [10/10] Adım 1400 | Loss G: 0.4412 | Loss D: 0.7402
# Epoch [10/10] Adım 1600 | Loss G: 0.6775 | Loss D: 0.6841
# Epoch [10/10] Adım 1800 | Loss G: 0.6205 | Loss D: 0.6768
# Epoch [10/10] Adım 2000 | Loss G: 0.5045 | Loss D: 0.7017
# Epoch [10/10] Adım 2200 | Loss G: 0.6385 | Loss D: 0.5884
# Epoch [10/10] Adım 2400 | Loss G: 0.4054 | Loss D: 0.6504
# Epoch [10/10] Adım 2600 | Loss G: 0.4988 | Loss D: 0.6836
# Epoch [10/10] Adım 2800 | Loss G: 0.5513 | Loss D: 0.6191
# [TAMAMLANDI] Epoch 10 Bitti. Ortalama Generator Kaybı: 0.5733
#  -> [KAYIT] Güncel Blind model Drive'a yedeklendi.
# ------------------------------------------------------------
#
# [EĞİTİM SONU] Blind model eğitimi bitti ve son model Drive'a başarıyla kaydedildi!

# %%
# ==============================================================================
# DİKKAT: YENİ BİR OTURUMDA BU HÜCREYİ ÇALIŞTIRMADAN ÖNCE ŞU HÜCRELERİ ÇALIŞTIR:
# 1. Ortam Kurulumu
# 2. Model Mimarisi - BlindHAT (Maskesiz Ablasyon Versiyonu)
# ==============================================================================

import torch
import os

print("[BİLGİ] MASKESİZ (Blind) model test aşaması başlatılıyor. Model Drive'dan yükleniyor...")

# Cihaz ayarı (GPU varsa GPU, yoksa CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Modeli oluştur (Ağırlıkları yükleyebilmek için iskelete ihtiyacımız var)
# NOT: Bu iskelet artık maskesiz (Blind) versiyonu içeriyor!
test_model = BlindHAT(img_size=128).to(device)

# Drive'daki maskesiz en iyi modelin yolu (İsme dikkat: blind_en_iyi_model.pth)
model_yolu = "/content/drive/MyDrive/Goruntu_Analizi_Projesi/Modeller/blind_en_iyi_model.pth"

if os.path.exists(model_yolu):
    try:
        # Model ağırlıklarını yükle
        test_model.load_state_dict(torch.load(model_yolu, map_location=device))
        test_model.eval() # Modeli test (değerlendirme) moduna alıyoruz
        print(f"[BAŞARILI] Blind (Maskesiz) model ağırlıkları başarıyla yüklendi!\nYol: {model_yolu}")

    except RuntimeError as e:
        print("\n[HATA] Ağırlıklar yüklenirken bir uyumsuzluk yaşandı!")
        print("Muhtemel Sebep: MaskGuided (Maskeli) bir modelin ağırlıklarını BlindHAT mimarisine yüklemeye çalışıyorsunuz.")
        print("Çözüm: Lütfen BlindHAT eğitiminin en az 1 epoch tamamlandığından ve 'blind_en_iyi_model.pth' dosyasının oluştuğundan emin olun.")
        # print(f"Hata Detayı: {e}") # Hata detayını görmek istersen başındaki diyezi kaldırabilirsin
else:
    print(f"[HATA] Model dosyası bulunamadı! Lütfen eğitim döngüsünün 'blind_en_iyi_model.pth' dosyasını oluşturduğundan emin olun:\n{model_yolu}")
# Out:
# [BİLGİ] MASKESİZ (Blind) model test aşaması başlatılıyor. Model Drive'dan yükleniyor...
# [BAŞARILI] Blind (Maskesiz) model ağırlıkları başarıyla yüklendi!
# Yol: /content/drive/MyDrive/Goruntu_Analizi_Projesi/Modeller/blind_en_iyi_model.pth

# %%
# ==============================================================================
# DİKKAT: YENİ BİR OTURUMDA BU HÜCREYİ ÇALIŞTIRMADAN ÖNCE ŞU HÜCRELERİ ÇALIŞTIRIN:
# 1. Veri Setinin Hazırlanması
# 2. Veri Yükleme ve Dataloader
# ==============================================================================

import matplotlib.pyplot as plt
import numpy as np
import torch

print("[İŞLEM] Belirtilen indekslerdeki görüntüler test ediliyor (MASKESİZ MODEL İÇİN)...")

# Senin incelemek istediğin spesifik görüntü sıraları (indeksler)
secilen_indeksler = [680, 629, 88, 35]

# Seçilen indekslerdeki verileri toplayıp yapay bir "batch" (grup) oluşturacağız
inputs_list = []
gt_imgs_list = []

for idx in secilen_indeksler:
    # İstenen indeksin test setinin boyutlarını aşıp aşmadığını kontrol et
    if idx >= len(test_dataset):
        print(f"[HATA] {idx}. sıra test veri setinde yok! (Maksimum sınır: {len(test_dataset)-1})")
        continue

    # Doğrudan test_dataset'in o sırasındaki sözlüğü (dictionary) alıyoruz
    ornek = test_dataset[idx]

    inputs_list.append(ornek['input'])
    # Maskeyi artık çekmemize gerek yok, doğrudan orijinal resmi alıyoruz
    gt_imgs_list.append(ornek['gt'])

# Eğer geçerli indeksler bulunduysa işlemlere devam et
if len(inputs_list) > 0:
    # Listeleri PyTorch tensörüne çevirip tek bir "batch" yapıyoruz ve GPU'ya yolluyoruz
    inputs = torch.stack(inputs_list).to(device)
    gt_imgs = torch.stack(gt_imgs_list).to(device)

    # Modelden tahmin alma (Gradients hesaplamaya gerek yok)
    with torch.no_grad():
        # DİKKAT: Maskesiz (Blind) model sadece onarılmış resmi döndürür!
        restored_imgs = test_model(inputs)

    # Görselleştirme için dinamik boyutlu figür oluştur (3 SÜTUN: Giriş, Çıktı, Orijinal)
    fig, axes = plt.subplots(len(inputs_list), 3, figsize=(12, 4 * len(inputs_list)))
    basliklar = ["Giriş Verisi (Lekeli)", "Onarılmış Görüntü (Maskesiz)", "Orijinal Görüntü"]

    for i in range(len(inputs_list)):
        # PyTorch tensörlerini (C, H, W) Numpy dizilerine (H, W, C) çevirip CPU'ya alıyoruz
        img_in = inputs[i].permute(1, 2, 0).cpu().numpy()
        img_restored = restored_imgs[i].permute(1, 2, 0).cpu().numpy()
        img_gt = gt_imgs[i].permute(1, 2, 0).cpu().numpy()

        gorseller = [img_in, img_restored, img_gt]

        for j in range(3):
            # Eğer sadece 1 resim varsa `axes` tek boyutlu olur, hata almamak için kontrol
            ax = axes[i, j] if len(inputs_list) > 1 else axes[j]

            # Değerleri 0-1 aralığında tutarak çizdiriyoruz
            ax.imshow(np.clip(gorseller[j], 0, 1))
            ax.axis('off')

            # Başlıkları sadece en üst satıra yaz
            if i == 0:
                ax.set_title(basliklar[j], fontsize=14, fontweight='bold')

            # Her satırın en soluna, hangi indeksi test ettiğimizi yazdıralım
            if j == 0:
                ax.text(-0.1, 0.5, f"İndeks:\n{secilen_indeksler[i]}",
                        va='center', ha='right', transform=ax.transAxes,
                        fontsize=12, fontweight='bold', color='darkred')

    plt.tight_layout()
    plt.show()
else:
    print("[HATA] Görselleştirilecek geçerli bir indeks bulunamadı.")
# Out:
# [İŞLEM] Belirtilen indekslerdeki görüntüler test ediliyor (MASKESİZ MODEL İÇİN)...

# %%
# RESTORASYON METRİKLERİ HESAPLAMA (MASKESİZ BLIND MODEL İÇİN)
import torch
import torch.nn.functional as F
import numpy as np
from skimage.metrics import structural_similarity as ssim

print("[İŞLEM] Tüm test seti üzerinden MASKESİZ (Blind) Modelin Restorasyon Metrikleri hesaplanıyor...\n")

toplam_psnr = 0.0
toplam_ssim = 0.0
toplam_mse = 0.0
ornek_sayisi = 0

# Modelin değerlendirme modunda olduğundan emin oluyoruz
test_model.eval()

with torch.no_grad():
    for batch in test_dataloader:
        inputs = batch['input'].to(device)
        gt_imgs = batch['gt'].to(device) # Gerçek temiz görüntüleri GPU'da tutuyoruz

        # --- KRİTİK GÜNCELLEME BURADA ---
        # DİKKAT: Maskesiz (Blind) model sadece tek bir çıktı (restored_imgs) verir!
        restored_imgs = test_model(inputs)

        # Çıktıları 0-1 aralığına sıkıştırıyoruz
        restored_imgs = torch.clamp(restored_imgs, 0.0, 1.0)

        for i in range(inputs.size(0)):
            y_true_gpu = gt_imgs[i]
            y_pred_gpu = restored_imgs[i]

            # ==========================================================
            # 1. GPU ÜZERİNDE HIZLI HESAPLAMALAR (MSE ve PSNR)
            # ==========================================================
            mse_gpu = F.mse_loss(y_pred_gpu, y_true_gpu)
            mse_degeri = mse_gpu.item()

            # PSNR Formülü
            if mse_degeri == 0:
                psnr_degeri = 100.0
            else:
                psnr_degeri = 10.0 * torch.log10(1.0 / mse_gpu).item()

            # ==========================================================
            # 2. CPU ÜZERİNDE HESAPLAMA (Sadece SSIM için)
            # ==========================================================
            gercek = y_true_gpu.permute(1, 2, 0).cpu().numpy()
            tahmin = y_pred_gpu.permute(1, 2, 0).cpu().numpy()

            ssim_degeri = ssim(gercek, tahmin, data_range=1.0, channel_axis=-1)

            # Toplamlara ekleme
            toplam_mse += mse_degeri
            toplam_psnr += psnr_degeri
            toplam_ssim += ssim_degeri
            ornek_sayisi += 1

print("="*40)
print("MASKESİZ (BLIND) MODEL METRİKLERİ")
print("="*40)
print(f"Ortalama PSNR : {toplam_psnr / ornek_sayisi:.4f} dB")
print(f"Ortalama SSIM : {toplam_ssim / ornek_sayisi:.4f}")
print(f"Ortalama MSE  : {toplam_mse / ornek_sayisi:.6f}")
print("="*40)
# Out:
# [İŞLEM] Tüm test seti üzerinden MASKESİZ (Blind) Modelin Restorasyon Metrikleri hesaplanıyor...
#
# ========================================
# MASKESİZ (BLIND) MODEL METRİKLERİ
# ========================================
# Ortalama PSNR : 37.7260 dB
# Ortalama SSIM : 0.9939
# Ortalama MSE  : 0.000211
# ========================================
